# %% [markdown]
# # Part 1: Join the Duet Server the Data Owner connected to

# %%
import syft as sy

# %%
duet = sy.join_duet('00212f9e7879d68af8d63308e7b0ecb3', network_url="http://ec2-18-218-7-180.us-east-2.compute.amazonaws.com:5000/")
# Out:
# 🎤  🎸  ♪♪♪ Joining Duet ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently in beta.
# ♫♫♫ > Use at your own risk.
#
#
#     > ❤️ Love Duet? Please consider supporting our community!
#     > https://github.com/sponsors/OpenMined
#
# ♫♫♫ > Punching through firewall to OpenGrid Network Node at:
# ♫♫♫ > http://ec2-18-218-7-180.us-east-2.compute.amazonaws.com:5000/
# ♫♫♫ >
# ♫♫♫ > ...waiting for response from OpenGrid Network...
# ♫♫♫ > DONE!
#
# ♫♫♫ > STEP 1: Send the following Duet Client ID to your duet partner!
# ♫♫♫ > Duet Client ID: 718be8dcdc2ec9536469ba8e9d145e9d
#
# ♫♫♫ > ...waiting for partner to connect...
# C:\Users\kinda\AppData\Roaming\Python\Python39\site-packages\aiortc\rtcdtlstransport.py:211: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   _openssl_assert(lib.SSL_CTX_use_certificate(ctx, self._cert._x509) == 1)  # type: ignore
# C:\Users\kinda\AppData\Roaming\Python\Python39\site-packages\aiortc\rtcdtlstransport.py:186: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   value=certificate_digest(self._cert._x509),  # type: ignore
# ♫♫♫ > CONNECTED!

# %% [markdown]
# ### <img src="https://github.com/OpenMined/design-assets/raw/master/logos/OM/mark-primary-light.png" alt="he-black-box" width="100"/> Checkpoint 0 : Now STOP and run the Data Owner notebook until Checkpoint 1.

# %% [markdown]
# # Part 2: Search for Available Data

# %%
# The data scientist can check the list of searchable data in Data Owner's duet store
duet.store.pandas
# Out:
#                                         ID    Tags  \
# 0  <UID: 974aa3c9538944868bc1ba3fb4cf0a6c>  [ages]
#
#                            Description             object_type
# 0  This is a list of ages of 6 people.  <class 'torch.Tensor'>

# %%
# Data Scientist likes the age data. (S)He needs a pointer to it.

data_ptr = duet.store[0] 
# data_ptr = duet.store['ages']

# data_ptr is a reference to the age dataset remotely available on data owner's server
print(data_ptr)
# Out:
# <syft.proxy.torch.TensorPointer object at 0x000001A6AD5C0850>

# %% [markdown]
# # Part 3: Perform some basic analysis on the data
# Now the data scientist can perform analysis on the data that is in the Data Owner's duet server, without the owner having to share his/her data.

# %% [markdown]
# ### Get average age

# %%
average_age = data_ptr.float().mean()

# %%
# Now the Data Scientist wants to download the result.

try:
    average_age.get()
except Exception as e:
    print(e)
# Out:
# [2022-08-10T00:46:09.312957+0900][CRITICAL][logger]][17748] You do not have permission to .get() Object with ID: <UID: 54133df9dffa45399cca5527a6064bdb>Please submit a request.
# You do not have permission to .get() Object with ID: <UID: 54133df9dffa45399cca5527a6064bdb>Please submit a request.

# %%
# Looks like the Data Scientist does not have permission to download this result! He/she needs
# to make a request to the Data Owner.

average_age.request(reason="Please approve!")

# %% [markdown]
# ### <img src="https://github.com/OpenMined/design-assets/raw/master/logos/OM/mark-primary-light.png" alt="he-black-box" width="100"/> Checkpoint 1 : Now STOP and run the Data Owner notebook until Checkpoint 2.

# %%
try:
    average_age.get()
except Exception as e:
    print(e)
# Out:
# [2022-08-10T00:48:58.050237+0900][CRITICAL][logger]][17748] You do not have permission to .get() Object with ID: <UID: 54133df9dffa45399cca5527a6064bdb>Please submit a request.
# You do not have permission to .get() Object with ID: <UID: 54133df9dffa45399cca5527a6064bdb>Please submit a request.

# %%
average_age.request(
    reason="I am a data scientist and I need to know the average age for my analysis."
)

# %%
duet.requests.pandas
# Out:
#   Requested Object's tags                                             Reason  \
# 0     [ages, float, mean]  I am a data scientist and I need to know the a...
#
#                                 Request ID  \
# 0  <UID: 1baf8cc2dcd341889437417ce1621088>
#
#                      Requested Object's ID Requested Object's type
# 0  <UID: 54133df9dffa45399cca5527a6064bdb>

# %% [markdown]
# ### <img src="https://github.com/OpenMined/design-assets/raw/master/logos/OM/mark-primary-light.png" alt="he-black-box" width="100"/> Checkpoint 2 : Now STOP and run the Data Owner notebook until the next checkpoint.

# %%
# Once the request is approved - the data scientist can download the result!
avg = average_age.get()
print(avg)
# Out:
# tensor(46.8333)

# %% [markdown]
# ### Get min and max age

# %%
duet.torch
# Out:
# Module:
# 	.Tensor -> <syft.ast.klass.Class object at 0x000001A6AD25BFA0>
# 	.BFloat16Tensor -> <syft.ast.klass.Class object at 0x000001A6AD28F040>
# 	.BoolTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F0A0>
# 	.ByteTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F100>
# 	.CharTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F160>
# 	.DoubleTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F1C0>
# 	.FloatTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F220>
# 	.HalfTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F280>
# 	.IntTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F2E0>
# 	.LongTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F340>
# 	.ShortTensor -> <syft.ast.klass.Class object at 0x000001A6AD28F3A0>
# 	.nn -> Module:
# 		.Parameter -> <syft.ast.klass.Class object at 0x000001A6AD28F4C0>
# 		.Module -> <syft.ast.klass.Class object at 0x000001A6AD31CA60>
# 		.Conv2d -> <syft.ast.klass.Class object at 0x000001A6AD31CF40>
# 		.Dropout2d -> <syft.ast.klass.Class object at 0x000001A6AD3223A0>
# 		.Linear -> <syft.ast.klass.Class object at 0x000001A6AD322700>
# 		.functional -> Module:
# 			.relu -> <syft.ast.callable.Callable object at 0x000001A6AD324040>
# 			.gelu -> <syft.ast.callable.Callable object at 0x000001A6AD3240A0>
# 			.max_pool2d -> <syft.ast.callable.Callable object at 0x000001A6AD324100>
# 			.log_softmax -> <syft.ast.callable.Callable object at 0x000001A6AD324160>
# 			.cosine_embedding_loss -> <syft.ast.callable.Callable object at 0x000001A6AD32CEE0>
# 			.ctc_loss -> <syft.ast.callable.Callable object at 0x000001A6AD32CF40>
# 			.hinge_embedding_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330040>
# 			.l1_loss -> <syft.ast.callable.Callable object at 0x000001A6AD3300A0>
# 			.margin_ranking_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330160>
# 			.mse_loss -> <syft.ast.callable.Callable object at 0x000001A6AD3301C0>
# 			.multi_margin_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330280>
# 			.multilabel_margin_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330340>
# 			.multilabel_soft_margin_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330400>
# 			.nll_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330460>
# 			.cross_entropy -> <syft.ast.callable.Callable object at 0x000001A6AD330520>
# 			.poisson_nll_loss -> <syft.ast.callable.Callable object at 0x000001A6AD3305E0>
# 			.smooth_l1_loss -> <syft.ast.callable.Callable object at 0x000001A6AD3306A0>
# 			.soft_margin_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330760>
# 			.triplet_margin_loss -> <syft.ast.callable.Callable object at 0x000001A6AD330820>
#
# 		.Sequential -> <syft.ast.klass.Class object at 0x000001A6AD32CB20>
# 		.AdaptiveLogSoftmaxWithLoss -> <syft.ast.klass.Class object at 0x000001A6AD3308E0>
# 		.BCELoss -> <syft.ast.klass.Class object at 0x000001A6AD330A60>
# 		.BCEWithLogitsLoss -> <syft.ast.klass.Class object at 0x000001A6AD330B20>
# 		.CTCLoss -> <syft.ast.klass.Class object at 0x000001A6AD330C40>
# 		.CrossEntropyLoss -> <syft.ast.klass.Class object at 0x000001A6AD330D00>
# 		.CosineEmbeddingLoss -> <syft.ast.klass.Class object at 0x000001A6AD330E20>
# 		.HingeEmbeddingLoss -> <syft.ast.klass.Class object at 0x000001A6AD330F40>
# 		.KLDivLoss -> <syft.ast.klass.Class object at 0x000001A6AD32F0A0>
# 		.L1Loss -> <syft.ast.klass.Class object at 0x000001A6AD32F160>
# 		.MSELoss -> <syft.ast.klass.Class object at 0x000001A6AD32F220>
# 		.MarginRankingLoss -> <syft.ast.klass.Class object at 0x000001A6AD32F2E0>
# 		.MultiLabelMarginLoss -> <syft.ast.klass.Class object at 0x000001A6AD32F400>
# 		.MultiLabelSoftMarginLoss -> <syft.ast.klass.Class object at 0x000001A6AD32F580>
# 		.MultiMarginLoss -> <syft.ast.klass.Class object at 0x000001A6AD32F6A0>
# 		.NLLLoss -> <syft.ast.klass.Class object at 0x000001A6AD32F7C0>
# 		.NLLLoss2d -> <syft.ast.klass.Class object at 0x000001A6AD32F880>
# 		.PoissonNLLLoss -> <syft.ast.klass.Class object at 0x000001A6AD32F940>
# 		.SmoothL1Loss -> <syft.ast.klass.Class object at 0x000001A6AD32FA60>
# 		.SoftMarginLoss -> <syft.ast.klass.Class object at 0x000001A6AD32FB20>
# 		.TripletMarginLoss -> <syft.ast.klass.Class object at 0x000001A6AD32FC40>
# 		.AdaptiveAvgPool1d -> <syft.ast.klass.Class object at 0x000001A6AD32FD60>
# 		.AdaptiveAvgPool2d -> <syft.ast.klass.Class object at 0x000001A6AD338400>
# 		.AdaptiveAvgPool3d -> <syft.ast.klass.Class object at 0x000001A6AD338A60>
# 		.AdaptiveMaxPool1d -> <syft.ast.klass.Class object at 0x000001A6AD33B100>
# 		.AdaptiveMaxPool2d -> <syft.ast.klass.Class object at 0x000001A6AD33B760>
# 		.AdaptiveMaxPool3d -> <syft.ast.klass.Class object at 0x000001A6AD33BDC0>
# 		.AlphaDropout -> <syft.ast.klass.Class object at 0x000001A6AD33E460>
# 		.AvgPool1d -> <syft.ast.klass.Class object at 0x000001A6AD33EA00>
# 		.AvgPool2d -> <syft.ast.klass.Class object at 0x000001A6AD33EE80>
# 		.AvgPool3d -> <syft.ast.klass.Class object at 0x000001A6AD341340>
# 		.BatchNorm1d -> <syft.ast.klass.Class object at 0x000001A6AD3417C0>
# 		.BatchNorm2d -> <syft.ast.klass.Class object at 0x000001A6AD341C40>
# 		.BatchNorm3d -> <syft.ast.klass.Class object at 0x000001A6AD345100>
# 		.Bilinear -> <syft.ast.klass.Class object at 0x000001A6AD345580>
# 		.CELU -> <syft.ast.klass.Class object at 0x000001A6AD345A00>
# 		.ConstantPad1d -> <syft.ast.klass.Class object at 0x000001A6AD345E20>
# 		.ConstantPad2d -> <syft.ast.klass.Class object at 0x000001A6AD348400>
# 		.ConstantPad3d -> <syft.ast.klass.Class object at 0x000001A6AD3489A0>
# 		.Container -> <syft.ast.klass.Class object at 0x000001A6AD348F40>
# 		.Conv1d -> <syft.ast.klass.Class object at 0x000001A6AD34C400>
# 		.Conv3d -> <syft.ast.klass.Class object at 0x000001A6AD34C820>
# 		.ConvTranspose1d -> <syft.ast.klass.Class object at 0x000001A6AD34CC40>
# 		.ConvTranspose2d -> <syft.ast.klass.Class object at 0x000001A6AD350280>
# 		.ConvTranspose3d -> <syft.ast.klass.Class object at 0x000001A6AD350880>
# 		.CosineSimilarity -> <syft.ast.klass.Class object at 0x000001A6AD350E80>
# 		.CrossMapLRN2d -> <syft.ast.klass.Class object at 0x000001A6AD3544C0>
# 		.DataParallel -> <syft.ast.klass.Class object at 0x000001A6AD354A60>
# 		.Dropout -> <syft.ast.klass.Class object at 0x000001A6AD356040>
# 		.Dropout3d -> <syft.ast.klass.Class object at 0x000001A6AD3565E0>
# 		.ELU -> <syft.ast.klass.Class object at 0x000001A6AD356A60>
# 		.Embedding -> <syft.ast.klass.Class object at 0x000001A6AD356E20>
# 		.EmbeddingBag -> <syft.ast.klass.Class object at 0x000001A6AD35C2E0>
# 		.FeatureAlphaDropout -> <syft.ast.klass.Class object at 0x000001A6AD35C880>
# 		.Flatten -> <syft.ast.klass.Class object at 0x000001A6AD35CFA0>
# 		.Fold -> <syft.ast.klass.Class object at 0x000001A6AD35E460>
# 		.FractionalMaxPool2d -> <syft.ast.klass.Class object at 0x000001A6AD35E880>
# 		.FractionalMaxPool3d -> <syft.ast.klass.Class object at 0x000001A6AD35EFA0>
# 		.GELU -> <syft.ast.klass.Class object at 0x000001A6AD362700>
# 		.GLU -> <syft.ast.klass.Class object at 0x000001A6AD362B20>
# 		.GRU -> <syft.ast.klass.Class object at 0x000001A6AD362EE0>
# 		.GRUCell -> <syft.ast.klass.Class object at 0x000001A6AD3652E0>
# 		.GroupNorm -> <syft.ast.klass.Class object at 0x000001A6AD365760>
# 		.Hardshrink -> <syft.ast.klass.Class object at 0x000001A6AD365BE0>
# 		.Hardsigmoid -> <syft.ast.klass.Class object at 0x000001A6AD36A0A0>
# 		.Hardswish -> <syft.ast.klass.Class object at 0x000001A6AD36A460>
# 		.Hardtanh -> <syft.ast.klass.Class object at 0x000001A6AD36A820>
# 		.Identity -> <syft.ast.klass.Class object at 0x000001A6AD36ACA0>
# 		.InstanceNorm1d -> <syft.ast.klass.Class object at 0x000001A6AD36F160>
# 		.InstanceNorm2d -> <syft.ast.klass.Class object at 0x000001A6AD36F760>
# 		.InstanceNorm3d -> <syft.ast.klass.Class object at 0x000001A6AD36FD60>
# 		.LPPool1d -> <syft.ast.klass.Class object at 0x000001A6AD3723A0>
# 		.LPPool2d -> <syft.ast.klass.Class object at 0x000001A6AD372820>
# 		.LSTM -> <syft.ast.klass.Class object at 0x000001A6AD372CA0>
# 		.LSTMCell -> <syft.ast.klass.Class object at 0x000001A6AD375100>
# 		.LayerNorm -> <syft.ast.klass.Class object at 0x000001A6AD375580>
# 		.LeakyReLU -> <syft.ast.klass.Class object at 0x000001A6AD375A00>
# 		.LocalResponseNorm -> <syft.ast.klass.Class object at 0x000001A6AD375E80>
# 		.LogSigmoid -> <syft.ast.klass.Class object at 0x000001A6AD37A520>
# 		.LogSoftmax -> <syft.ast.klass.Class object at 0x000001A6AD37A9A0>
# 		.MaxPool1d -> <syft.ast.klass.Class object at 0x000001A6AD37AE20>
# 		.MaxPool2d -> <syft.ast.klass.Class object at 0x000001A6AD37E2E0>
# 		.MaxPool3d -> <syft.ast.klass.Class object at 0x000001A6AD37E760>
# 		.MaxUnpool1d -> <syft.ast.klass.Class object at 0x000001A6AD37EBE0>
# 		.MaxUnpool2d -> <syft.ast.klass.Class object at 0x000001A6AD3810A0>
# 		.MaxUnpool3d -> <syft.ast.klass.Class object at 0x000001A6AD381520>
# 		.ModuleDict -> <syft.ast.klass.Class object at 0x000001A6AD3819A0>
# 		.ModuleList -> <syft.ast.klass.Class object at 0x000001A6AD381E20>
# 		.MultiheadAttention -> <syft.ast.klass.Class object at 0x000001A6AD3853A0>
# 		.PReLU -> <syft.ast.klass.Class object at 0x000001A6AD385A60>
# 		.PairwiseDistance -> <syft.ast.klass.Class object at 0x000001A6AD385E80>
# 		.PixelShuffle -> <syft.ast.klass.Class object at 0x000001A6AD38B4C0>
# 		.RNN -> <syft.ast.klass.Class object at 0x000001A6AD38BA60>
# 		.RNNBase -> <syft.ast.klass.Class object at 0x000001A6AD38BE20>
# 		.RNNCell -> <syft.ast.klass.Class object at 0x000001A6AD38D2E0>
# 		.RNNCellBase -> <syft.ast.klass.Class object at 0x000001A6AD38D760>
# 		.RReLU -> <syft.ast.klass.Class object at 0x000001A6AD38DBE0>
# 		.ReLU -> <syft.ast.klass.Class object at 0x000001A6AD392040>
# 		.ReLU6 -> <syft.ast.klass.Class object at 0x000001A6AD392460>
# 		.ReflectionPad1d -> <syft.ast.klass.Class object at 0x000001A6AD392880>
# 		.ReflectionPad2d -> <syft.ast.klass.Class object at 0x000001A6AD392E80>
# 		.ReplicationPad1d -> <syft.ast.klass.Class object at 0x000001A6AD3954C0>
# 		.ReplicationPad2d -> <syft.ast.klass.Class object at 0x000001A6AD395AC0>
# 		.ReplicationPad3d -> <syft.ast.klass.Class object at 0x000001A6AD399100>
# 		.SELU -> <syft.ast.klass.Class object at 0x000001A6AD399700>
# 		.Sigmoid -> <syft.ast.klass.Class object at 0x000001A6AD399CA0>
# 		.Softmax -> <syft.ast.klass.Class object at 0x000001A6AD39C160>
# 		.Softmax2d -> <syft.ast.klass.Class object at 0x000001A6AD39C5E0>
# 		.Softmin -> <syft.ast.klass.Class object at 0x000001A6AD39CA60>
# 		.Softplus -> <syft.ast.klass.Class object at 0x000001A6AD39CEE0>
# 		.Softshrink -> <syft.ast.klass.Class object at 0x000001A6AD3A03A0>
# 		.Softsign -> <syft.ast.klass.Class object at 0x000001A6AD3A0820>
# 		.SyncBatchNorm -> <syft.ast.klass.Class object at 0x000001A6AD3A0CA0>
# 		.Tanh -> <syft.ast.klass.Class object at 0x000001A6AD3A4280>
# 		.Tanhshrink -> <syft.ast.klass.Class object at 0x000001A6AD3A46A0>
# 		.Threshold -> <syft.ast.klass.Class object at 0x000001A6AD3A4B20>
# 		.Transformer -> <syft.ast.klass.Class object at 0x000001A6AD3A4FA0>
# 		.TransformerDecoder -> <syft.ast.klass.Class object at 0x000001A6AD3A9460>
# 		.TransformerDecoderLayer -> <syft.ast.klass.Class object at 0x000001A6AD3A9B80>
# 		.TransformerEncoder -> <syft.ast.klass.Class object at 0x000001A6AD3AC220>
# 		.TransformerEncoderLayer -> <syft.ast.klass.Class object at 0x000001A6AD3AC940>
# 		.Unfold -> <syft.ast.klass.Class object at 0x000001A6AD3ACFA0>
# 		.Upsample -> <syft.ast.klass.Class object at 0x000001A6AD3AF400>
# 		.UpsamplingBilinear2d -> <syft.ast.klass.Class object at 0x000001A6AD3AF880>
# 		.UpsamplingNearest2d -> <syft.ast.klass.Class object at 0x000001A6AD3AFF40>
# 		.ZeroPad2d -> <syft.ast.klass.Class object at 0x000001A6AD3B26A0>
#
# 	.return_types -> Module:
# 		.cummax -> <syft.ast.klass.Class object at 0x000001A6AD2A4220>
# 		.cummin -> <syft.ast.klass.Class object at 0x000001A6AD2A4280>
# 		.eig -> <syft.ast.klass.Class object at 0x000001A6AD2A42E0>
# 		.kthvalue -> <syft.ast.klass.Class object at 0x000001A6AD2A4340>
# 		.lstsq -> <syft.ast.klass.Class object at 0x000001A6AD2A43A0>
# 		.slogdet -> <syft.ast.klass.Class object at 0x000001A6AD2A4400>
# 		.qr -> <syft.ast.klass.Class object at 0x000001A6AD2A4460>
# 		.mode -> <syft.ast.klass.Class object at 0x000001A6AD2A44C0>
# 		.solve -> <syft.ast.klass.Class object at 0x000001A6AD2A4520>
# 		.sort -> <syft.ast.klass.Class object at 0x000001A6AD2A4580>
# 		.symeig -> <syft.ast.klass.Class object at 0x000001A6AD2A45E0>
# 		.topk -> <syft.ast.klass.Class object at 0x000001A6AD2A4640>
# 		.triangular_solve -> <syft.ast.klass.Class object at 0x000001A6AD2A4700>
# 		.svd -> <syft.ast.klass.Class object at 0x000001A6AD2A4760>
# 		.geqrf -> <syft.ast.klass.Class object at 0x000001A6AD2A47C0>
# 		.median -> <syft.ast.klass.Class object at 0x000001A6AD2A4820>
# 		.max -> <syft.ast.klass.Class object at 0x000001A6AD2A4880>
# 		.min -> <syft.ast.klass.Class object at 0x000001A6AD2A48E0>
#
# 	.Size -> <syft.ast.klass.Class object at 0x000001A6AD2F9AC0>
# 	.set_grad_enabled -> <syft.ast.klass.Class object at 0x000001A6AD2F9DC0>
# 	.zeros -> <syft.ast.callable.Callable object at 0x000001A6AD2F9E20>
# 	.randn -> <syft.ast.callable.Callable object at 0x000001A6AD2F9E80>
# 	.ones_like -> <syft.ast.callable.Callable object at 0x000001A6AD2F9EE0>
# 	.arange -> <syft.ast.callable.Callable object at 0x000001A6AD2FD040>
# 	.abs_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FD0A0>
# 	.abs -> <syft.ast.callable.Callable object at 0x000001A6AD2FD100>
# 	.acos_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FD160>
# 	.acos -> <syft.ast.callable.Callable object at 0x000001A6AD2FD1C0>
# 	.add -> <syft.ast.callable.Callable object at 0x000001A6AD2FD220>
# 	.addbmm -> <syft.ast.callable.Callable object at 0x000001A6AD2FD280>
# 	.addcdiv -> <syft.ast.callable.Callable object at 0x000001A6AD2FD2E0>
# 	.addcmul -> <syft.ast.callable.Callable object at 0x000001A6AD2FD340>
# 	.addmm -> <syft.ast.callable.Callable object at 0x000001A6AD2FD3A0>
# 	.addmv_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FD400>
# 	.addmv -> <syft.ast.callable.Callable object at 0x000001A6AD2FD460>
# 	.addr -> <syft.ast.callable.Callable object at 0x000001A6AD2FD4C0>
# 	.all -> <syft.ast.callable.Callable object at 0x000001A6AD2FD520>
# 	.allclose -> <syft.ast.callable.Callable object at 0x000001A6AD2FD580>
# 	.angle -> <syft.ast.callable.Callable object at 0x000001A6AD2FD5E0>
# 	.any -> <syft.ast.callable.Callable object at 0x000001A6AD2FD640>
# 	.argmax -> <syft.ast.callable.Callable object at 0x000001A6AD2FD6A0>
# 	.argmin -> <syft.ast.callable.Callable object at 0x000001A6AD2FD700>
# 	.argsort -> <syft.ast.callable.Callable object at 0x000001A6AD2FD760>
# 	.as_strided_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FD7C0>
# 	.as_strided -> <syft.ast.callable.Callable object at 0x000001A6AD2FD820>
# 	.asin_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FD880>
# 	.asin -> <syft.ast.callable.Callable object at 0x000001A6AD2FD8E0>
# 	.atan_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FD940>
# 	.atan -> <syft.ast.callable.Callable object at 0x000001A6AD2FD9A0>
# 	.atan2 -> <syft.ast.callable.Callable object at 0x000001A6AD2FDA00>
# 	.baddbmm -> <syft.ast.callable.Callable object at 0x000001A6AD2FDA60>
# 	.bernoulli -> <syft.ast.callable.Callable object at 0x000001A6AD2FDAC0>
# 	.bitwise_and -> <syft.ast.callable.Callable object at 0x000001A6AD2FDB20>
# 	.bitwise_not -> <syft.ast.callable.Callable object at 0x000001A6AD2FDB80>
# 	.bitwise_or -> <syft.ast.callable.Callable object at 0x000001A6AD2FDBE0>
# 	.bitwise_xor -> <syft.ast.callable.Callable object at 0x000001A6AD2FDC40>
# 	.bmm -> <syft.ast.callable.Callable object at 0x000001A6AD2FDCA0>
# 	.cat -> <syft.ast.callable.Callable object at 0x000001A6AD2FDD00>
# 	.ceil_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FDD60>
# 	.ceil -> <syft.ast.callable.Callable object at 0x000001A6AD2FDDC0>
# 	.cholesky_inverse -> <syft.ast.callable.Callable object at 0x000001A6AD2FDE20>
# 	.cholesky_solve -> <syft.ast.callable.Callable object at 0x000001A6AD2FDE80>
# 	.cholesky -> <syft.ast.callable.Callable object at 0x000001A6AD2FDEE0>
# 	.chunk -> <syft.ast.callable.Callable object at 0x000001A6AD2FDF40>
# 	.clamp_ -> <syft.ast.callable.Callable object at 0x000001A6AD2FDFA0>
# 	.clamp_max_ -> <syft.ast.callable.Callable object at 0x000001A6AD302040>
# 	.clamp_max -> <syft.ast.callable.Callable object at 0x000001A6AD3020A0>
# 	.clamp_min_ -> <syft.ast.callable.Callable object at 0x000001A6AD302100>
# 	.clamp_min -> <syft.ast.callable.Callable object at 0x000001A6AD302160>
# 	.clamp -> <syft.ast.callable.Callable object at 0x000001A6AD3021C0>
# 	.clone -> <syft.ast.callable.Callable object at 0x000001A6AD302220>
# 	.conj -> <syft.ast.callable.Callable object at 0x000001A6AD302280>
# 	.cos_ -> <syft.ast.callable.Callable object at 0x000001A6AD3022E0>
# 	.cos -> <syft.ast.callable.Callable object at 0x000001A6AD302340>
# 	.cosh_ -> <syft.ast.callable.Callable object at 0x000001A6AD3023A0>
# 	.cosh -> <syft.ast.callable.Callable object at 0x000001A6AD302400>
# 	.cross -> <syft.ast.callable.Callable object at 0x000001A6AD302460>
# 	.cummax -> <syft.ast.callable.Callable object at 0x000001A6AD3024C0>
# 	.cummin -> <syft.ast.callable.Callable object at 0x000001A6AD302520>
# 	.cumprod -> <syft.ast.callable.Callable object at 0x000001A6AD302580>
# 	.cumsum -> <syft.ast.callable.Callable object at 0x000001A6AD3025E0>
# 	.dequantize -> <syft.ast.callable.Callable object at 0x000001A6AD302640>
# 	.det -> <syft.ast.callable.Callable object at 0x000001A6AD3026A0>
# 	.detach -> <syft.ast.callable.Callable object at 0x000001A6AD302700>
# 	.diag_embed -> <syft.ast.callable.Callable object at 0x000001A6AD302760>
# 	.diag -> <syft.ast.callable.Callable object at 0x000001A6AD3027C0>
# 	.diagflat -> <syft.ast.callable.Callable object at 0x000001A6AD302820>
# 	.diagonal -> <syft.ast.callable.Callable object at 0x000001A6AD302880>
# 	.digamma -> <syft.ast.callable.Callable object at 0x000001A6AD3028E0>
# 	.dist -> <syft.ast.callable.Callable object at 0x000001A6AD302940>
# 	.div -> <syft.ast.callable.Callable object at 0x000001A6AD3029A0>
# 	.dot -> <syft.ast.callable.Callable object at 0x000001A6AD302A00>
# 	.eig -> <syft.ast.callable.Callable object at 0x000001A6AD302A60>
# 	.eq -> <syft.ast.callable.Callable object at 0x000001A6AD302AC0>
# 	.equal -> <syft.ast.callable.Callable object at 0x000001A6AD302B20>
# 	.erf_ -> <syft.ast.callable.Callable object at 0x000001A6AD302B80>
# 	.erf -> <syft.ast.callable.Callable object at 0x000001A6AD302BE0>
# 	.erfc_ -> <syft.ast.callable.Callable object at 0x000001A6AD302C40>
# 	.erfc -> <syft.ast.callable.Callable object at 0x000001A6AD302CA0>
# 	.erfinv -> <syft.ast.callable.Callable object at 0x000001A6AD302D00>
# 	.exp_ -> <syft.ast.callable.Callable object at 0x000001A6AD302D60>
# 	.exp -> <syft.ast.callable.Callable object at 0x000001A6AD302DC0>
# 	.expm1_ -> <syft.ast.callable.Callable object at 0x000001A6AD302E20>
# 	.expm1 -> <syft.ast.callable.Callable object at 0x000001A6AD302E80>
# 	.fft -> Module:
#
# 	.fill_ -> <syft.ast.callable.Callable object at 0x000001A6AD302F40>
# 	.flatten -> <syft.ast.callable.Callable object at 0x000001A6AD302FA0>
# 	.flip -> <syft.ast.callable.Callable object at 0x000001A6AD305040>
# 	.floor_ -> <syft.ast.callable.Callable object at 0x000001A6AD3050A0>
# 	.floor_divide -> <syft.ast.callable.Callable object at 0x000001A6AD305100>
# 	.floor -> <syft.ast.callable.Callable object at 0x000001A6AD305160>
# 	.fmod -> <syft.ast.callable.Callable object at 0x000001A6AD3051C0>
# 	.frac_ -> <syft.ast.callable.Callable object at 0x000001A6AD305220>
# 	.frac -> <syft.ast.callable.Callable object at 0x000001A6AD305280>
# 	.from_numpy -> <syft.ast.callable.Callable object at 0x000001A6AD3052E0>
# 	.gather -> <syft.ast.callable.Callable object at 0x000001A6AD305340>
# 	.ge -> <syft.ast.callable.Callable object at 0x000001A6AD3053A0>
# 	.geqrf -> <syft.ast.callable.Callable object at 0x000001A6AD305400>
# 	.ger -> <syft.ast.callable.Callable object at 0x000001A6AD305460>
# 	.get_device -> <syft.ast.callable.Callable object at 0x000001A6AD3054C0>
# 	.gt -> <syft.ast.callable.Callable object at 0x000001A6AD305520>
# 	.hardshrink -> <syft.ast.callable.Callable object at 0x000001A6AD305580>
# 	.histc -> <syft.ast.callable.Callable object at 0x000001A6AD3055E0>
# 	.index_add -> <syft.ast.callable.Callable object at 0x000001A6AD305640>
# 	.index_copy -> <syft.ast.callable.Callable object at 0x000001A6AD3056A0>
# 	.index_fill -> <syft.ast.callable.Callable object at 0x000001A6AD305700>
# 	.index_put_ -> <syft.ast.callable.Callable object at 0x000001A6AD305760>
# 	.index_put -> <syft.ast.callable.Callable object at 0x000001A6AD3057C0>
# 	.index_select -> <syft.ast.callable.Callable object at 0x000001A6AD305820>
# 	.int_repr -> <syft.ast.callable.Callable object at 0x000001A6AD305880>
# 	.inverse -> <syft.ast.callable.Callable object at 0x000001A6AD3058E0>
# 	.is_complex -> <syft.ast.callable.Callable object at 0x000001A6AD305940>
# 	.is_distributed -> <syft.ast.callable.Callable object at 0x000001A6AD3059A0>
# 	.is_floating_point -> <syft.ast.callable.Callable object at 0x000001A6AD305A00>
# 	.is_nonzero -> <syft.ast.callable.Callable object at 0x000001A6AD305A60>
# 	.is_same_size -> <syft.ast.callable.Callable object at 0x000001A6AD305AC0>
# 	.is_signed -> <syft.ast.callable.Callable object at 0x000001A6AD305B20>
# 	.isclose -> <syft.ast.callable.Callable object at 0x000001A6AD305B80>
# 	.kthvalue -> <syft.ast.callable.Callable object at 0x000001A6AD305BE0>
# 	.le -> <syft.ast.callable.Callable object at 0x000001A6AD305C40>
# 	.lerp -> <syft.ast.callable.Callable object at 0x000001A6AD305CA0>
# 	.lgamma -> <syft.ast.callable.Callable object at 0x000001A6AD305D00>
# 	.log_ -> <syft.ast.callable.Callable object at 0x000001A6AD305D60>
# 	.log_softmax -> <syft.ast.callable.Callable object at 0x000001A6AD305DC0>
# 	.log -> <syft.ast.callable.Callable object at 0x000001A6AD305E20>
# 	.log10_ -> <syft.ast.callable.Callable object at 0x000001A6AD305E80>
# 	.log10 -> <syft.ast.callable.Callable object at 0x000001A6AD305EE0>
# 	.log1p_ -> <syft.ast.callable.Callable object at 0x000001A6AD305F40>
# 	.log1p -> <syft.ast.callable.Callable object at 0x000001A6AD305FA0>
# 	.log2_ -> <syft.ast.callable.Callable object at 0x000001A6AD30A040>
# 	.log2 -> <syft.ast.callable.Callable object at 0x000001A6AD30A0A0>
# 	.logdet -> <syft.ast.callable.Callable object at 0x000001A6AD30A100>
# 	.logical_and -> <syft.ast.callable.Callable object at 0x000001A6AD30A160>
# 	.logical_not -> <syft.ast.callable.Callable object at 0x000001A6AD30A1C0>
# 	.logical_or -> <syft.ast.callable.Callable object at 0x000001A6AD30A220>
# 	.logical_xor -> <syft.ast.callable.Callable object at 0x000001A6AD30A280>
# 	.logsumexp -> <syft.ast.callable.Callable object at 0x000001A6AD30A2E0>
# 	.lstsq -> <syft.ast.callable.Callable object at 0x000001A6AD30A340>
# 	.lt -> <syft.ast.callable.Callable object at 0x000001A6AD30A3A0>
# 	.lu_solve -> <syft.ast.callable.Callable object at 0x000001A6AD30A400>
# 	.lu -> <syft.ast.callable.Callable object at 0x000001A6AD30A460>
# 	.masked_fill -> <syft.ast.callable.Callable object at 0x000001A6AD30A4C0>
# 	.masked_scatter -> <syft.ast.callable.Callable object at 0x000001A6AD30A520>
# 	.masked_select -> <syft.ast.callable.Callable object at 0x000001A6AD30A580>
# 	.matmul -> <syft.ast.callable.Callable object at 0x000001A6AD30A5E0>
# 	.matrix_power -> <syft.ast.callable.Callable object at 0x000001A6AD30A640>
# 	.mean -> <syft.ast.callable.Callable object at 0x000001A6AD30A6A0>
# 	.mm -> <syft.ast.callable.Callable object at 0x000001A6AD30A700>
# 	.mode -> <syft.ast.callable.Callable object at 0x000001A6AD30A760>
# 	.mul -> <syft.ast.callable.Callable object at 0x000001A6AD30A7C0>
# 	.multinomial -> <syft.ast.callable.Callable object at 0x000001A6AD30A820>
# 	.mv -> <syft.ast.callable.Callable object at 0x000001A6AD30A880>
# 	.mvlgamma -> <syft.ast.callable.Callable object at 0x000001A6AD30A8E0>
# 	.narrow -> <syft.ast.callable.Callable object at 0x000001A6AD30A940>
# 	.ne -> <syft.ast.callable.Callable object at 0x000001A6AD30A9A0>
# 	.neg_ -> <syft.ast.callable.Callable object at 0x000001A6AD30AA00>
# 	.neg -> <syft.ast.callable.Callable object at 0x000001A6AD30AA60>
# 	.nonzero -> <syft.ast.callable.Callable object at 0x000001A6AD30AAC0>
# 	.norm -> <syft.ast.callable.Callable object at 0x000001A6AD30AB20>
# 	.orgqr -> <syft.ast.callable.Callable object at 0x000001A6AD30AB80>
# 	.ormqr -> <syft.ast.callable.Callable object at 0x000001A6AD30ABE0>
# 	.pinverse -> <syft.ast.callable.Callable object at 0x000001A6AD30AC40>
# 	.polygamma -> <syft.ast.callable.Callable object at 0x000001A6AD30ACA0>
# 	.pow -> <syft.ast.callable.Callable object at 0x000001A6AD30AD00>
# 	.prelu -> <syft.ast.callable.Callable object at 0x000001A6AD30AD60>
# 	.q_per_channel_axis -> <syft.ast.callable.Callable object at 0x000001A6AD30ADC0>
# 	.q_per_channel_scales -> <syft.ast.callable.Callable object at 0x000001A6AD30AE20>
# 	.q_per_channel_zero_points -> <syft.ast.callable.Callable object at 0x000001A6AD30AE80>
# 	.q_scale -> <syft.ast.callable.Callable object at 0x000001A6AD30AEE0>
# 	.q_zero_point -> <syft.ast.callable.Callable object at 0x000001A6AD30AF40>
# 	.qr -> <syft.ast.callable.Callable object at 0x000001A6AD30AFA0>
# 	.reciprocal_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E040>
# 	.reciprocal -> <syft.ast.callable.Callable object at 0x000001A6AD30E0A0>
# 	.relu_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E100>
# 	.relu -> <syft.ast.callable.Callable object at 0x000001A6AD30E160>
# 	.remainder -> <syft.ast.callable.Callable object at 0x000001A6AD30E1C0>
# 	.renorm -> <syft.ast.callable.Callable object at 0x000001A6AD30E220>
# 	.repeat_interleave -> <syft.ast.callable.Callable object at 0x000001A6AD30E280>
# 	.reshape -> <syft.ast.callable.Callable object at 0x000001A6AD30E2E0>
# 	.resize_as_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E340>
# 	.roll -> <syft.ast.callable.Callable object at 0x000001A6AD30E3A0>
# 	.rot90 -> <syft.ast.callable.Callable object at 0x000001A6AD30E400>
# 	.round_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E460>
# 	.round -> <syft.ast.callable.Callable object at 0x000001A6AD30E4C0>
# 	.rsqrt_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E520>
# 	.rsqrt -> <syft.ast.callable.Callable object at 0x000001A6AD30E580>
# 	.scatter_add -> <syft.ast.callable.Callable object at 0x000001A6AD30E5E0>
# 	.scatter -> <syft.ast.callable.Callable object at 0x000001A6AD30E640>
# 	.select -> <syft.ast.callable.Callable object at 0x000001A6AD30E6A0>
# 	.sigmoid_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E700>
# 	.sigmoid -> <syft.ast.callable.Callable object at 0x000001A6AD30E760>
# 	.sign -> <syft.ast.callable.Callable object at 0x000001A6AD30E7C0>
# 	.sin_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E820>
# 	.sin -> <syft.ast.callable.Callable object at 0x000001A6AD30E880>
# 	.sinh_ -> <syft.ast.callable.Callable object at 0x000001A6AD30E8E0>
# 	.sinh -> <syft.ast.callable.Callable object at 0x000001A6AD30E940>
# 	.slogdet -> <syft.ast.callable.Callable object at 0x000001A6AD30E9A0>
# 	.softmax -> <syft.ast.callable.Callable object at 0x000001A6AD30EA00>
# 	.solve -> <syft.ast.callable.Callable object at 0x000001A6AD30EA60>
# 	.sort -> <syft.ast.callable.Callable object at 0x000001A6AD30EAC0>
# 	.split_with_sizes -> <syft.ast.callable.Callable object at 0x000001A6AD30EB20>
# 	.split -> <syft.ast.callable.Callable object at 0x000001A6AD30EB80>
# 	.sqrt_ -> <syft.ast.callable.Callable object at 0x000001A6AD30EBE0>
# 	.sqrt -> <syft.ast.callable.Callable object at 0x000001A6AD30EC40>
# 	.square_ -> <syft.ast.callable.Callable object at 0x000001A6AD30ECA0>
# 	.square -> <syft.ast.callable.Callable object at 0x000001A6AD30ED00>
# 	.squeeze -> <syft.ast.callable.Callable object at 0x000001A6AD30ED60>
# 	.stack -> <syft.ast.callable.Callable object at 0x000001A6AD30EDC0>
# 	.std -> <syft.ast.callable.Callable object at 0x000001A6AD30EE20>
# 	.stft -> <syft.ast.callable.Callable object at 0x000001A6AD30EE80>
# 	.sub -> <syft.ast.callable.Callable object at 0x000001A6AD30EEE0>
# 	.sum -> <syft.ast.callable.Callable object at 0x000001A6AD30EF40>
# 	.svd -> <syft.ast.callable.Callable object at 0x000001A6AD30EFA0>
# 	.symeig -> <syft.ast.callable.Callable object at 0x000001A6AD313040>
# 	.t -> <syft.ast.callable.Callable object at 0x000001A6AD3130A0>
# 	.take -> <syft.ast.callable.Callable object at 0x000001A6AD313100>
# 	.tan_ -> <syft.ast.callable.Callable object at 0x000001A6AD313160>
# 	.tan -> <syft.ast.callable.Callable object at 0x000001A6AD3131C0>
# 	.tanh_ -> <syft.ast.callable.Callable object at 0x000001A6AD313220>
# 	.tanh -> <syft.ast.callable.Callable object at 0x000001A6AD313280>
# 	.topk -> <syft.ast.callable.Callable object at 0x000001A6AD3132E0>
# 	.trace -> <syft.ast.callable.Callable object at 0x000001A6AD313340>
# 	.transpose -> <syft.ast.callable.Callable object at 0x000001A6AD3133A0>
# 	.triangular_solve -> <syft.ast.callable.Callable object at 0x000001A6AD313400>
# 	.tril -> <syft.ast.callable.Callable object at 0x000001A6AD313460>
# 	.triu -> <syft.ast.callable.Callable object at 0x000001A6AD3134C0>
# 	.true_divide -> <syft.ast.callable.Callable object at 0x000001A6AD313520>
# 	.trunc_ -> <syft.ast.callable.Callable object at 0x000001A6AD313580>
# 	.trunc -> <syft.ast.callable.Callable object at 0x000001A6AD3135E0>
# 	.unique_consecutive -> <syft.ast.callable.Callable object at 0x000001A6AD313640>
# 	.unique -> <syft.ast.callable.Callable object at 0x000001A6AD3136A0>
# 	.unsqueeze -> <syft.ast.callable.Callable object at 0x000001A6AD313700>
# 	.var -> <syft.ast.callable.Callable object at 0x000001A6AD313760>
# 	.unsafe_chunk -> <syft.ast.callable.Callable object at 0x000001A6AD3137C0>
# 	.absolute -> <syft.ast.callable.Callable object at 0x000001A6AD313820>
# 	.acosh_ -> <syft.ast.callable.Callable object at 0x000001A6AD313880>
# 	.acosh -> <syft.ast.callable.Callable object at 0x000001A6AD3138E0>
# 	.asinh_ -> <syft.ast.callable.Callable object at 0x000001A6AD313940>
# 	.asinh -> <syft.ast.callable.Callable object at 0x000001A6AD3139A0>
# 	.atanh_ -> <syft.ast.callable.Callable object at 0x000001A6AD313A00>
# 	.atanh -> <syft.ast.callable.Callable object at 0x000001A6AD313A60>
# 	.deg2rad_ -> <syft.ast.callable.Callable object at 0x000001A6AD313AC0>
# 	.deg2rad -> <syft.ast.callable.Callable object at 0x000001A6AD313B20>
# 	.fliplr -> <syft.ast.callable.Callable object at 0x000001A6AD313B80>
# 	.flipud -> <syft.ast.callable.Callable object at 0x000001A6AD313BE0>
# 	.isfinite -> <syft.ast.callable.Callable object at 0x000001A6AD313C40>
# 	.isinf -> <syft.ast.callable.Callable object at 0x000001A6AD313CA0>
# 	.isnan -> <syft.ast.callable.Callable object at 0x000001A6AD0F05E0>
# 	.logaddexp -> <syft.ast.callable.Callable object at 0x000001A6AD313D00>
# 	.logaddexp2 -> <syft.ast.callable.Callable object at 0x000001A6AD313D60>
# 	.logcumsumexp -> <syft.ast.callable.Callable object at 0x000001A6AD313DC0>
# 	.rad2deg_ -> <syft.ast.callable.Callable object at 0x000001A6AD313E20>
# 	.rad2deg -> <syft.ast.callable.Callable object at 0x000001A6AD313E80>
# 	.istft -> <syft.ast.callable.Callable object at 0x000001A6AD313EE0>
# 	.amax -> <syft.ast.callable.Callable object at 0x000001A6AD313F40>
# 	.amin -> <syft.ast.callable.Callable object at 0x000001A6AD313FA0>
# 	.arccos -> <syft.ast.callable.Callable object at 0x000001A6AD317040>
# 	.arccos_ -> <syft.ast.callable.Callable object at 0x000001A6AD3170A0>
# 	.arccosh -> <syft.ast.callable.Callable object at 0x000001A6AD317100>
# 	.arccosh_ -> <syft.ast.callable.Callable object at 0x000001A6AD317160>
# 	.arcsin -> <syft.ast.callable.Callable object at 0x000001A6AD3171C0>
# 	.arcsin_ -> <syft.ast.callable.Callable object at 0x000001A6AD317220>
# 	.arcsinh -> <syft.ast.callable.Callable object at 0x000001A6AD317280>
# 	.arcsinh_ -> <syft.ast.callable.Callable object at 0x000001A6AD3172E0>
# 	.arctan -> <syft.ast.callable.Callable object at 0x000001A6AD317340>
# 	.arctan_ -> <syft.ast.callable.Callable object at 0x000001A6AD3173A0>
# 	.arctanh -> <syft.ast.callable.Callable object at 0x000001A6AD317400>
# 	.arctanh_ -> <syft.ast.callable.Callable object at 0x000001A6AD317460>
# 	.clip -> <syft.ast.callable.Callable object at 0x000001A6AD3174C0>
# 	.clip_ -> <syft.ast.callable.Callable object at 0x000001A6AD317520>
# 	.count_nonzero -> <syft.ast.callable.Callable object at 0x000001A6AD317580>
# 	.divide -> <syft.ast.callable.Callable object at 0x000001A6AD3175E0>
# 	.exp2 -> <syft.ast.callable.Callable object at 0x000001A6AD3176A0>
# 	.exp2_ -> <syft.ast.callable.Callable object at 0x000001A6AD317700>
# 	.fix -> <syft.ast.callable.Callable object at 0x000001A6AD317760>
# 	.fix_ -> <syft.ast.callable.Callable object at 0x000001A6AD3177C0>
# 	.gcd -> <syft.ast.callable.Callable object at 0x000001A6AD317820>
# 	.gcd_ -> <syft.ast.callable.Callable object at 0x000001A6AD317880>
# 	.greater -> <syft.ast.callable.Callable object at 0x000001A6AD3178E0>
# 	.greater_equal -> <syft.ast.callable.Callable object at 0x000001A6AD317940>
# 	.heaviside -> <syft.ast.callable.Callable object at 0x000001A6AD3179A0>
# 	.hypot -> <syft.ast.callable.Callable object at 0x000001A6AD317A00>
# 	.i0 -> <syft.ast.callable.Callable object at 0x000001A6AD317A60>
# 	.i0_ -> <syft.ast.callable.Callable object at 0x000001A6AD317AC0>
# 	.isneginf -> <syft.ast.callable.Callable object at 0x000001A6AD317B20>
# 	.isposinf -> <syft.ast.callable.Callable object at 0x000001A6AD317B80>
# 	.isreal -> <syft.ast.callable.Callable object at 0x000001A6AD317BE0>
# 	.lcm -> <syft.ast.callable.Callable object at 0x000001A6AD317C40>
# 	.lcm_ -> <syft.ast.callable.Callable object at 0x000001A6AD317CA0>
# 	.less -> <syft.ast.callable.Callable object at 0x000001A6AD317D00>
# 	.less_equal -> <syft.ast.callable.Callable object at 0x000001A6AD317D60>
# 	.logit -> <syft.ast.callable.Callable object at 0x000001A6AD317DC0>
# 	.logit_ -> <syft.ast.callable.Callable object at 0x000001A6AD317E20>
# 	.maximum -> <syft.ast.callable.Callable object at 0x000001A6AD317E80>
# 	.minimum -> <syft.ast.callable.Callable object at 0x000001A6AD317EE0>
# 	.matrix_exp -> <syft.ast.callable.Callable object at 0x000001A6AD317F40>
# 	.multiply -> <syft.ast.callable.Callable object at 0x000001A6AD317FA0>
# 	.nanquantile -> <syft.ast.callable.Callable object at 0x000001A6AD31C040>
# 	.nansum -> <syft.ast.callable.Callable object at 0x000001A6AD31C0A0>
# 	.negative -> <syft.ast.callable.Callable object at 0x000001A6AD31C100>
# 	.negative_ -> <syft.ast.callable.Callable object at 0x000001A6AD31C160>
# 	.nextafter -> <syft.ast.callable.Callable object at 0x000001A6AD31C1C0>
# 	.outer -> <syft.ast.callable.Callable object at 0x000001A6AD31C220>
# 	.quantile -> <syft.ast.callable.Callable object at 0x000001A6AD31C280>
# 	.sgn -> <syft.ast.callable.Callable object at 0x000001A6AD31C2E0>
# 	.signbit -> <syft.ast.callable.Callable object at 0x000001A6AD31C340>
# 	.subtract -> <syft.ast.callable.Callable object at 0x000001A6AD31C3A0>
# 	.unsafe_split -> <syft.ast.callable.Callable object at 0x000001A6AD31C400>
# 	.vdot -> <syft.ast.callable.Callable object at 0x000001A6AD31C460>
# 	.movedim -> <syft.ast.callable.Callable object at 0x000001A6AD31C4C0>
# 	.unsafe_split_with_sizes -> <syft.ast.callable.Callable object at 0x000001A6AD31C520>
# 	.cuda -> Module:
# 		.is_available -> <syft.ast.callable.Callable object at 0x000001A6AD31C5E0>
#
# 	.device -> <syft.ast.klass.Class object at 0x000001A6AD31C640>
# 	.random -> Module:
# 		.initial_seed -> <syft.ast.callable.Callable object at 0x000001A6AD31C7C0>
#
# 	.zeros_like -> <syft.ast.callable.Callable object at 0x000001A6AD31C820>
# 	.manual_seed -> <syft.ast.callable.Callable object at 0x000001A6AD31C880>
# 	.Generator -> <syft.ast.klass.Class object at 0x000001A6AD31C8E0>
# 	.utils -> Module:
# 		.data -> Module:
# 			.DataLoader -> <syft.ast.klass.Class object at 0x000001A6AD322BE0>
# 			.dataloader -> Module:
# 				._SingleProcessDataLoaderIter -> <syft.ast.klass.Class object at 0x000001A6AD322E20>
#
#
#
# 	.optim -> Module:
# 		.ASGD -> <syft.ast.klass.Class object at 0x000001A6AD324220>
# 		.Adadelta -> <syft.ast.klass.Class object at 0x000001A6AD3243A0>
# 		.Adagrad -> <syft.ast.klass.Class object at 0x000001A6AD324520>
# 		.Adam -> <syft.ast.klass.Class object at 0x000001A6AD3246A0>
# 		.AdamW -> <syft.ast.klass.Class object at 0x000001A6AD324820>
# 		.Adamax -> <syft.ast.klass.Class object at 0x000001A6AD3249A0>
# 		.LBFGS -> <syft.ast.klass.Class object at 0x000001A6AD324B20>
# 		.Optimizer -> <syft.ast.klass.Class object at 0x000001A6AD324CA0>
# 		.RMSprop -> <syft.ast.klass.Class object at 0x000001A6AD324E80>
# 		.Rprop -> <syft.ast.klass.Class object at 0x000001A6AD32C040>
# 		.SGD -> <syft.ast.klass.Class object at 0x000001A6AD32C1C0>
# 		.SparseAdam -> <syft.ast.klass.Class object at 0x000001A6AD32C340>
# 		.lr_scheduler -> Module:
# 			.StepLR -> <syft.ast.klass.Class object at 0x000001A6AD32C5E0>
#
#
# 	.no_grad -> <syft.ast.klass.Class object at 0x000001A6AD32C7C0>
# 	.autograd -> Module:
# 		.grad_mode -> Module:
# 			.no_grad -> <syft.ast.klass.Class object at 0x000001A6AD32C940>
#
#
# 	.distributions -> Module:
# 		.Categorical -> <syft.ast.klass.Class object at 0x000001A6AD3B2B80>
#
# 	.kron -> <syft.ast.callable.Callable object at 0x000001A6AD3B6160>
# 	.msort -> <syft.ast.callable.Callable object at 0x000001A6AD3B6280>
# 	.row_stack -> <syft.ast.callable.Callable object at 0x000001A6AD3B62E0>
# 	.moveaxis -> <syft.ast.callable.Callable object at 0x000001A6AD3B65E0>
# 	.tensor_split -> <syft.ast.callable.Callable object at 0x000001A6AD3B6700>
# 	.tile -> <syft.ast.callable.Callable object at 0x000001A6AD3B6820>
# 	.fmin -> <syft.ast.callable.Callable object at 0x000001A6AD3B6A00>
# 	.ldexp -> <syft.ast.callable.Callable object at 0x000001A6AD3B6A60>
# 	.igamma -> <syft.ast.callable.Callable object at 0x000001A6AD3B6B80>
# 	.float_power -> <syft.ast.callable.Callable object at 0x000001A6AD3BA0A0>
# 	.xlogy -> <syft.ast.callable.Callable object at 0x000001A6AD3BA1C0>
# 	.copysign -> <syft.ast.callable.Callable object at 0x000001A6AD3BA220>
# 	.nanmedian -> <syft.ast.callable.Callable object at 0x000001A6AD3BA280>
# 	.igammac -> <syft.ast.callable.Callable object at 0x000001A6AD3BA2E0>
# 	.diff -> <syft.ast.callable.Callable object at 0x000001A6AD3BA400>
# 	.sinc -> <syft.ast.callable.Callable object at 0x000001A6AD3BA520>
# 	.column_stack -> <syft.ast.callable.Callable object at 0x000001A6AD3BA700>
# 	.pixel_unshuffle -> <syft.ast.callable.Callable object at 0x000001A6AD3BA820>
# 	.swapaxes -> <syft.ast.callable.Callable object at 0x000001A6AD3BAAC0>
# 	.nan_to_num -> <syft.ast.callable.Callable object at 0x000001A6AD3BAB20>
# 	.inner -> <syft.ast.callable.Callable object at 0x000001A6AD3BAB80>
# 	.fmax -> <syft.ast.callable.Callable object at 0x000001A6AD3BABE0>
# 	.ravel -> <syft.ast.callable.Callable object at 0x000001A6AD3BAF40>
# 	.broadcast_to -> <syft.ast.callable.Callable object at 0x000001A6AD3BAFA0>
# 	.swapdims -> <syft.ast.callable.Callable object at 0x000001A6AD3BE1C0>

# %%
max_age_ptr = data_ptr.float().amax()
min_age_ptr = data_ptr.float().amin()

# %%
max_age_result = max_age_ptr.get(
    request_block=True,
    reason="download the maximum age",
    timeout_secs=10,
)

print(max_age_result)
# Out:
# tensor(88.)

# %%
min_age_result = min_age_ptr.get(
    request_block=True,
    reason="download the minimum age",
    timeout_secs=10,
)

print(min_age_result)
# Out:
# tensor(22.)

# %% [markdown]
# ## Let's cheat!

# %%
age_data = data_ptr.get(request_block=True, delete_obj=False)

print(age_data)
# Out:
# tensor([25, 32, 49, 65, 88, 22])

# %% [markdown]
# Please note in the later releases there will be features for the verification of the requests made by data scientists so that they cannot be exploited in anyway. In later courses different techniques for making this whole process more robust will be covered. So stay tuned!
#
# For this course, it is a great way for you to debug your codes and sanity check!

# %% [markdown]
# ### <img src="https://github.com/OpenMined/design-assets/raw/master/logos/OM/mark-primary-light.png" alt="he-black-box" width="100"/> Checkpoint 3 : Well done!
